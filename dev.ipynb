# %%
import plotly.express as px
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
import plotly.graph_objects as go
import pandas as pd

import seperate

# %%
abso = 'C:/Users/uhlse/OneDrive/Desktop/Stuff/Projects/pixels in 3D space/'
seperate.do(abso+'img/img2.jpg')
# Out:
# (15, 10, 3)
# (150, 3)
# (158, 3)

# %%
abso = 'C:/Users/uhlse/OneDrive/Desktop/Stuff/Projects/pixels in 3D space/'
image_path = abso+'img/img2.jpg'
image, _ = seperate.load_image(image_path)
image = seperate.scale_down(image, 80)
fig = seperate.seperate_plot(image, save_html=False)
fig.show()
# Out:
# (127, 80, 3)
# (10160, 3)
# (9872, 3)
